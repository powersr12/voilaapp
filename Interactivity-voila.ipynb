# %%
# General Purpose
import numpy as np
from matplotlib import pyplot as plt

# Jupyter Specifics
from ipywidgets.widgets import interact, FloatSlider

# %matplotlib widget

# %%
x = np.linspace(0, 2 * np.pi)
fig, ax = plt.subplots(figsize=(4, 4))   
w=1
line, =ax.plot(x, np.sin(w*x))
ax.set_ylim(-1.01, 1.01)
ax.set_xlim(-0.1, 7)

fig.canvas.toolbar_visible=False
fig.canvas.header_visible=False
fig.canvas.footer_visible=False
fig.canvas.resizable=False

def update(w):
    line.set_ydata(np.sin(w*x))
   
interact(update, w=FloatSlider(min=0.5, max=4, step=0.1, value=1.0, description='w'));
# Out:
# interactive(children=(FloatSlider(value=1.0, description='w', max=4.0, min=0.5), Output()), _dom_classes=('wid…
# Canvas(footer_visible=False, header_visible=False, resizable=False, toolbar=Toolbar(toolitems=[('Home', 'Reset…
